# %%
# Data representation and computation
import pandas as pd  
import numpy as np  
pd.options.display.float_format = '{:20,.4f}'.format

# Graph plotting
import matplotlib.pyplot as plt  
import seaborn as sns

# prophet by Facebook
from fbprophet import Prophet

# Miscellaneous
import warnings
from math import log, e, ceil
from scipy.stats import entropy
#from prettytable import PrettyTable

# Declaration
warnings.filterwarnings('ignore')
# %precision 2
# %matplotlib inline
sns.set(font_scale=1)

# %%
file_path = "Resources/Sales_Data - Only the columns we need.csv"
sales_df = pd.read_csv(file_path)
sales_df.head()
# Out:
#    YEAR_  MONTH_     InvDate     InvNumber Market InvCustomer  \
# 0   2013       7  07/04/2013  NA0223010005    CAN      CALL01
# 1   2013       7  07/04/2013  NA0223010003    CAN      SWAL01
# 2   2013       7  07/04/2013  NA0223010004    CAN      CALL01
# 3   2013       7  07/04/2013  NA0223010005    CAN      CALL01
# 4   2013       7  07/04/2013  NA0223010004    CAN      CALL01
#
#        CompanyName ItemClass SubCategory Flavours  Product  \
# 0  Callace & Warey       ORG         F&N   CASHEW   600065
# 1           Swalbo       ORG         F&N   CASHEW   600065
# 2  Callace & Warey       ORG         F&N   CASHEW   600065
# 3  Callace & Warey       ORG         F&N    APPLE   600071
# 4  Callace & Warey       ORG         F&N    APPLE   600071
#
#                      Description            Config UOM  Real_Qty  \
# 0     NAT CAN  Cashew Nut Fiesta  Organic 40gx16x8  CS         1
# 1     NAT CAN  Cashew Nut Fiesta  Organic 40gx16x8  CS        22
# 2     NAT CAN  Cashew Nut Fiesta  Organic 40gx16x8  CS         3
# 3  NAT CAN Niagara Apple Country  Organic 40gx16x8  CS         2
# 4  NAT CAN Niagara Apple Country  Organic 40gx16x8  CS         4
#
#              CAD_Value
# 0             153.6000
# 1           2,731.5200
# 2             460.8000
# 3             307.2000
# 4             614.4000

# %%
sales_df.shape
# Out:
# (35948, 16)

# %%
# The data is of a particular time period. 
# To read the data as a time series, we have to pass special arguments to the read_csv command:
dateparse = lambda dates: pd.datetime.strptime(dates, '%m/%d/%Y')

# %%
sales_df = pd.read_csv(file_path, parse_dates=['InvDate'], date_parser = dateparse)
sales_df.head()
# Out:
#    YEAR_  MONTH_    InvDate     InvNumber Market InvCustomer      CompanyName  \
# 0   2013       7 2013-07-04  NA0223010005    CAN      CALL01  Callace & Warey
# 1   2013       7 2013-07-04  NA0223010003    CAN      SWAL01           Swalbo
# 2   2013       7 2013-07-04  NA0223010004    CAN      CALL01  Callace & Warey
# 3   2013       7 2013-07-04  NA0223010005    CAN      CALL01  Callace & Warey
# 4   2013       7 2013-07-04  NA0223010004    CAN      CALL01  Callace & Warey
#
#   ItemClass SubCategory Flavours  Product                    Description  \
# 0       ORG         F&N   CASHEW   600065     NAT CAN  Cashew Nut Fiesta
# 1       ORG         F&N   CASHEW   600065     NAT CAN  Cashew Nut Fiesta
# 2       ORG         F&N   CASHEW   600065     NAT CAN  Cashew Nut Fiesta
# 3       ORG         F&N    APPLE   600071  NAT CAN Niagara Apple Country
# 4       ORG         F&N    APPLE   600071  NAT CAN Niagara Apple Country
#
#              Config UOM  Real_Qty            CAD_Value
# 0  Organic 40gx16x8  CS         1             153.6000
# 1  Organic 40gx16x8  CS        22           2,731.5200
# 2  Organic 40gx16x8  CS         3             460.8000
# 3  Organic 40gx16x8  CS         2             307.2000
# 4  Organic 40gx16x8  CS         4             614.4000

# %%
sales_df.shape
# Out:
# (35948, 16)

# %%
sales_df.describe()
# Out:
#                      YEAR_               MONTH_              Product  \
# count          35,948.0000          35,948.0000          35,948.0000
# mean            2,016.8881               6.5288         600,743.3911
# std                 2.5006               3.2983             313.4058
# min             2,013.0000               1.0000         600,007.0000
# 25%             2,015.0000               4.0000         600,627.0000
# 50%             2,017.0000               6.0000         600,773.5000
# 75%             2,019.0000               9.0000         600,919.0000
# max             2,021.0000              12.0000         601,307.0000
#
#                   Real_Qty            CAD_Value
# count          35,948.0000          35,948.0000
# mean               60.0658           4,029.2229
# std               327.3413          13,568.9165
# min                 1.0000               0.0000
# 25%                 2.0000             130.7000
# 50%                 5.0000             490.5600
# 75%                28.0000           2,105.5760
# max            11,520.0000         261,584.6400

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35948 entries, 0 to 35947
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   YEAR_        35948 non-null  int64
#  1   MONTH_       35948 non-null  int64
#  2   InvDate      35948 non-null  datetime64[ns]
#  3   InvNumber    35948 non-null  object
#  4   Market       35948 non-null  object
#  5   InvCustomer  35948 non-null  object
#  6   CompanyName  35948 non-null  object
#  7   ItemClass    35948 non-null  object
#  8   SubCategory  35948 non-null  object
#  9   Flavours     35948 non-null  object
#  10  Product      35948 non-null  int64
#  11  Description  35948 non-null  object
#  12  Config       35948 non-null  object
#  13  UOM          35948 non-null  object
#  14  Real_Qty     35948 non-null  int64
#  15  CAD_Value    35948 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(4), object(10)
# memory usage: 4.4+ MB

# %%
sales_df.isna().sum()
# Out:
# YEAR_          0
# MONTH_         0
# InvDate        0
# InvNumber      0
# Market         0
# InvCustomer    0
# CompanyName    0
# ItemClass      0
# SubCategory    0
# Flavours       0
# Product        0
# Description    0
# Config         0
# UOM            0
# Real_Qty       0
# CAD_Value      0
# dtype: int64

# %%
sales_df.groupby('SubCategory')['CAD_Value'].describe()
# Out:
#                            count                 mean                  std  \
# SubCategory
# CHOC                  1,102.0000           2,182.6657           5,869.2311
# F&N                  30,261.0000           4,399.6510          14,199.5907
# GRAN                  3,388.0000           1,538.4345           6,225.9932
# LSUG                    647.0000             278.9067             407.2594
# PROT                    550.0000           7,103.0887          23,553.7860
#
#                              min                  25%                  50%  \
# SubCategory
# CHOC                      0.0000             268.1800             536.3600
# F&N                       0.0000             134.0900             536.3600
# GRAN                      0.0000               9.1000              34.5600
# LSUG                      0.0000             100.8000             201.1400
# PROT                      0.0000             166.4000             456.7680
#
#                              75%                  max
# SubCategory
# CHOC                  2,395.8264          95,988.0000
# F&N                   2,227.4560         261,584.6400
# GRAN                    777.6000          94,027.2000
# LSUG                    302.4000           6,350.4000
# PROT                    998.4000         176,256.0000

# %%
sales_df.groupby('SubCategory')['Real_Qty','CAD_Value'].sum()
#sales.df.groupby('Market')['Customers', 'Sales'].sum()
# Out:
#              Real_Qty            CAD_Value
# SubCategory
# CHOC            19222       2,405,297.6046
# F&N           1609668     133,137,839.6553
# GRAN           304879       5,212,216.0100
# LSUG             1802         180,452.6500
# PROT           223674       3,906,698.7880

# %%
# sales trends
sns.factorplot(data = sales_df, x = 'MONTH_', y = "CAD_Value", 
               col = 'SubCategory', # per store type in cols
               palette = 'plasma',
               hue = 'SubCategory',
               row = 'Market')

# %%
# sales trends
sns.factorplot(data = sales_df, x = 'MONTH_', y = "Real_Qty", 
               col = 'SubCategory', # per subcategory in cols
               palette = 'plasma',
               hue = 'SubCategory',
               row = 'Market')

# %%
# sales_df.loc["CAN","PROT","CAD_Value"] Trying to find our sales for CAN market and PROT subcategory
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-36-dca6db069715> in <module>
# ----> 1 sales_df.loc["CAN","PROT","CAD_Value"]
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     887                     # AttributeError for IntervalTree get_value
#     888                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 889             return self._getitem_tuple(key)
#     890         else:
#     891             # we by definition only have the 0th axis
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1061
#    1062         # no multi-index, so validate all of the indexers
# -> 1063         self._has_valid_tuple(tup)
#    1064
#    1065         # ugly hack for GH #836
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\core\indexing.py in _has_valid_tuple(self, key)
#     718         Check the key for valid keys across my indexer.
#     719         """
# --> 720         self._validate_key_length(key)
#     721         for i, k in enumerate(key):
#     722             try:
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\core\indexing.py in _validate_key_length(self, key)
#     759     def _validate_key_length(self, key: Sequence[Any]) -> None:
#     760         if len(key) > self.ndim:
# --> 761             raise IndexingError("Too many indexers")
#     762
#     763     def _getitem_tuple_same_dim(self, tup: Tuple):
#
# IndexingError: Too many indexers

# %%
# sales for the CAN Market
sales = sales_df[sales_df.Market == "CAN"].loc[:,["InvDate","CAD_Value"]]

# reverse to the order: from 2013 to 2021
sales = sales.sort_index(ascending = False)

# to datetime64
sales['InvDate'] = pd.DatetimeIndex(sales['InvDate'])
sales.dtypes
# Out:
# InvDate      datetime64[ns]
# CAD_Value           float64
# dtype: object

# %%
# from the prophet documentation every variables should have specific names
sales = sales.rename(columns = {'InvDate': 'ds',
                                'CAD_Value': 'y'})
sales.head()
# Out:
#               ds                    y
# 35947 2021-06-29              28.9900
# 35946 2021-06-29              57.9800
# 35945 2021-06-29               4.9900
# 35944 2021-06-29              28.9900
# 35943 2021-06-29          15,924.0000

# %%
# Plot Daily Sales for CAN Market
ax = sales.set_index('ds').plot(figsize = (16, 4))
ax.set_ylabel('Daily Number of Sales')
ax.set_xlabel('Date')
plt.show()

# %%
# sales for the INTL Market
sales_INTL = sales_df[sales_df.Market == "INTL"].loc[:,["InvDate","CAD_Value"]]

# reverse to the order: from 2013 to 2021
sales_INTL = sales_INTL.sort_index(ascending = False)

# to datetime64
sales_INTL['InvDate'] = pd.DatetimeIndex(sales_INTL['InvDate'])
sales_INTL.dtypes
# Out:
# InvDate      datetime64[ns]
# CAD_Value           float64
# dtype: object

# %%
sales_INTL = sales_INTL.rename(columns = {'InvDate': 'ds',
                                'CAD_Value': 'y'})
sales_INTL.head()
# Out:
#               ds                    y
# 35924 2021-06-28           1,350.7200
# 35923 2021-06-28             731.6400
# 35922 2021-06-28           4,841.2056
# 35921 2021-06-28           5,071.7392
# 35920 2021-06-28           1,547.7000

# %%
# Plot Daily Sales for INTL Market
ax = sales_INTL.set_index('ds').plot(figsize = (16, 4))
ax.set_ylabel('Daily Number of Sales')
ax.set_xlabel('Date')
plt.show()

# %%
# set the uncertainty interval to 95% (the Prophet default is 80%)
my_model = Prophet(interval_width = 0.95, daily_seasonality=False)
my_model.fit(sales)

# dataframe that extends into future 6 weeks dataframe that extends into future 8 weeks 
future_dates = my_model.make_future_dataframe(periods = 8*7)

future_dates.tail(7)
# Out:
#              ds
# 1783 2021-08-18
# 1784 2021-08-19
# 1785 2021-08-20
# 1786 2021-08-21
# 1787 2021-08-22
# 1788 2021-08-23
# 1789 2021-08-24

# %%
# predictions
forecast = my_model.predict(future_dates)

# preditions for last week
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail(7)
# Out:
#              ds                 yhat           yhat_lower           yhat_upper
# 1783 2021-08-18          -1,169.5748         -28,415.6665          28,533.3809
# 1784 2021-08-19             402.2948         -29,248.0229          28,573.3350
# 1785 2021-08-20             837.5777         -29,747.5806          29,486.4582
# 1786 2021-08-21             141.5027         -29,091.3248          28,309.4600
# 1787 2021-08-22          -1,194.8744         -32,289.2141          27,443.3451
# 1788 2021-08-23            -368.4980         -28,819.6755          29,614.0701
# 1789 2021-08-24            -492.2968         -27,657.1481          28,074.7498

# %%
fc = forecast[['ds', 'yhat']].rename(columns = {'Date': 'ds', 'Forecast': 'yhat'})

# %%
# visualizing predicions
my_model.plot(forecast);

# %%
my_model.plot_components(forecast);

# %%
# set the uncertainty interval to 95% for INTL Market (the Prophet default is 80%)
my_model_INTL = Prophet(interval_width = 0.95, daily_seasonality=False)
my_model_INTL.fit(sales_INTL)

# dataframe that extends into future 6 weeks dataframe that extends into future 8 weeks 
future_dates_INTL = my_model_INTL.make_future_dataframe(periods = 8*7)

future_dates_INTL.tail(7)
# Out:
#             ds
# 428 2021-08-17
# 429 2021-08-18
# 430 2021-08-19
# 431 2021-08-20
# 432 2021-08-21
# 433 2021-08-22
# 434 2021-08-23

# %%
# predictions for INTL market
forecast_INTL = my_model_INTL.predict(future_dates_INTL)

# preditions for last week
forecast_INTL[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail(7)
# Out:
#             ds                 yhat           yhat_lower           yhat_upper
# 428 2021-08-17           5,045.3074          -5,612.6660          15,587.6725
# 429 2021-08-18           5,598.4961          -4,282.0928          15,967.4916
# 430 2021-08-19           4,687.9284          -5,715.8289          15,001.9680
# 431 2021-08-20           4,805.8891          -5,794.2632          15,222.7752
# 432 2021-08-21           3,107.6458          -6,504.7598          13,420.8238
# 433 2021-08-22           3,071.6986          -6,477.1767          13,232.4450
# 434 2021-08-23           4,400.4712          -5,943.4754          13,818.9842

# %%
fc_INTL = forecast_INTL[['ds', 'yhat']].rename(columns = {'Date': 'ds', 'Forecast': 'yhat'})

# %%
# visualizing predicions
my_model_INTL.plot(forecast_INTL);

# %%
my_model_INTL.plot_components(forecast_INTL);

# %%
# sales for the US Market
sales_US = sales_df[sales_df.Market == "US"].loc[:,["InvDate","CAD_Value"]]

# reverse to the order: from 2013 to 2021
sales_US = sales_US.sort_index(ascending = False)

# to datetime64
sales_US['InvDate'] = pd.DatetimeIndex(sales_US['InvDate'])
sales_US.dtypes
# Out:
# InvDate      datetime64[ns]
# CAD_Value           float64
# dtype: object

# %%
sales_US = sales_US.rename(columns = {'InvDate': 'ds',
                                'CAD_Value': 'y'})
sales_US.head()
# Out:
#               ds                    y
# 18889 2017-06-15               0.0000
# 18888 2017-06-15               0.0000
# 18884 2017-06-15               0.0000
# 18881 2017-06-15               0.0000
# 18102 2017-04-17               0.0000

# %%
# Plot Daily Sales for US Market
ax = sales_US.set_index('ds').plot(figsize = (16, 4))
ax.set_ylabel('Daily Number of Sales')
ax.set_xlabel('Date')
plt.show()

# %%
# set the uncertainty interval to 95% (the Prophet default is 80%)
my_model_US = Prophet(interval_width = 0.95, daily_seasonality=False)
my_model_US.fit(sales_US)

# dataframe that extends into future 6 weeks dataframe that extends into future 8 weeks 
future_dates_US = my_model_US.make_future_dataframe(periods = 8*7)

future_dates_US.tail(7)
# Out:
#             ds
# 250 2017-08-04
# 251 2017-08-05
# 252 2017-08-06
# 253 2017-08-07
# 254 2017-08-08
# 255 2017-08-09
# 256 2017-08-10

# %%
# predictions for US market
forecast_US = my_model_US.predict(future_dates_US)

# preditions for last week
forecast_US[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail(7)
# Out:
#             ds                 yhat           yhat_lower           yhat_upper
# 250 2017-08-04          -1,162.1981         -18,046.5015          17,824.8906
# 251 2017-08-05            -525.5606         -18,547.9142          17,394.4890
# 252 2017-08-06            -305.8957         -17,577.3939          16,233.0605
# 253 2017-08-07           3,221.0082         -14,742.8716          20,491.5504
# 254 2017-08-08            -160.3053         -18,088.9005          17,454.8972
# 255 2017-08-09          -1,494.4195         -19,652.2648          15,958.1577
# 256 2017-08-10             825.7577         -16,736.7982          17,614.4834

# %%
fc_US = forecast_US[['ds', 'yhat']].rename(columns = {'Date': 'ds', 'Forecast': 'yhat'})

# %%
# visualizing predicions
my_model_US.plot(forecast_US);

# %%
my_model_INTL.plot_components(forecast_INTL);
